# %% [markdown]
# # Food Sales Predictions
# Hannah Ploutz

# %% [markdown]
# ### Functions

# %%
## Create a function to take the true and predicted values
## and print MAE, MSE, RMSE, and R2 metrics

def model_metrics(pipe, X_train, y_train, X_test, y_test, 
                       model_name='Regression Model'):
  
  """Takes a regression model, training features and target and testing 
  features and target.
  Returns a dataframe of regression metrics"""

  ## Predictions
  train_pred = pipe.predict(X_train)
  test_pred = pipe.predict(X_test)
  
  metrics = ['train_MAE','test_MAE', 
             'train_RMSE', 'test_RMSE', 
             'train_R2', 'test_R2']
  
  ## Train
  train_mae = round(mean_absolute_error(y_train, train_pred),4)
  train_rmse = round(np.sqrt(mean_squared_error(y_train, train_pred)),4)
  train_r2 = round(r2_score(y_train, train_pred),4)

  ## Test
  test_mae = round(mean_absolute_error(y_test, test_pred),4)
  test_rmse = round(np.sqrt(mean_squared_error(y_test, test_pred)),4)
  test_r2 = round(r2_score(y_test, test_pred),4)

  ## Output Dataframe
  scores = pd.DataFrame(columns=metrics, index=[f'{model_name}'])
  scores.loc[f'{model_name}', :] = [train_mae, test_mae,
                                          train_rmse, test_rmse,
                                          train_r2, test_r2]

  return scores

# %%
def evaluate_regression(model, X_train,y_train, X_test, y_test,for_slides=True): 
    """Evaluates a scikit learn regression model using r-squared and RMSE
    FOR SLIDES VERS DOES MULTIPLE PRINT STATEMENTS FOR VERTICAL DISPLAY OF INFO"""
    
    ## Training Data
    y_pred_train = model.predict(X_train)
    r2_train = metrics.r2_score(y_train, y_pred_train)
    rmse_train = metrics.mean_squared_error(y_train, y_pred_train, 
                                            squared=False)
    mae_train = metrics.mean_absolute_error(y_train, y_pred_train)
    

    ## Test Data
    y_pred_test = model.predict(X_test)
    r2_test = metrics.r2_score(y_test, y_pred_test)
    rmse_test = metrics.mean_squared_error(y_test, y_pred_test, 
                                            squared=False)
    mae_test = metrics.mean_absolute_error(y_test, y_pred_test)
    
    if for_slides:
        df_version =[['Split','R^2','MAE','RMSE']]
        df_version.append(['Train',r2_train, mae_train, rmse_train])
        df_version.append(['Test',r2_test, mae_test, rmse_test])
        df_results = pd.DataFrame(df_version[1:], columns=df_version[0])
        df_results = df_results.round(2)
        display(df_results.style.hide(axis='index').format(precision=2, thousands=','))
        
    else: 
        print(f"Training Data:\tR^2 = {r2_train:,.2f}\tRMSE = {rmse_train:,.2f}\tMAE = {mae_train:,.2f}")
        print(f"Test Data:\tR^2 = {r2_test:,.2f}\tRMSE = {rmse_test:,.2f}\tMAE = {mae_test:,.2f}")

# %%
def get_importances(model, feature_names=None,name='Feature Importance',
                   sort=False, ascending=True):
    
    ## checking for feature names
    if feature_names == None:
        feature_names = model.feature_names_in_
        
    ## Saving the feature importances
    importances = pd.Series(model.feature_importances_, index= feature_names,
                           name=name)
    
    # sort importances
    if sort == True:
        importances = importances.sort_values(ascending=ascending)
        
    return importances

# %%
def plot_importance(importances, top_n=None,  figsize=(8,6)):
    # sorting with asc=false for correct order of bars
    if top_n==None:
        ## sort all features and set title
        plot_vals = importances.sort_values()
        title = "All Features - Ranked by Importance"
    else:
        ## sort features and keep top_n and set title
        plot_vals = importances.sort_values().tail(top_n)
        title = f"Top {top_n} Most Important Features"
    ## plotting top N importances
    ax = plot_vals.plot(kind='barh', figsize=figsize)
    ax.set(xlabel='Importance',
            ylabel='Feature Names',
            title=title)
    ## return ax in case want to continue to update/modify figure
    return ax

# %%
def get_color_dict(importances, color_rest='#006ba4' , color_top='green',
                    top_n=7):
    ## color -coding top 5 bars
    highlight_feats = importances.sort_values(ascending=True).tail(top_n).index
    colors_dict = {col: color_top if col in highlight_feats else color_rest for col in importances.index}
    return colors_dict

# %%
def plot_importance_color_ax(importances, top_n=None,  figsize=(8,6), 
                          color_dict=None, ax=None):
    
    # sorting with asc=false for correct order of bars
    if top_n==None:
        ## sort all features and set title
        plot_vals = importances.sort_values()
        title = "All Features - Ranked by Importance"
    else:
        ## sort features and keep top_n and set title
        plot_vals = importances.sort_values().tail(top_n)
        title = f"Top {top_n} Most Important Features"
    ## create plot with colors, if provided
    if color_dict is not None:
        ## Getting color list and saving to plot_kws
        colors = plot_vals.index.map(color_dict)
        ax = plot_vals.plot(kind='barh', figsize=figsize, color=colors, ax=ax)
        
    else:
        ## create plot without colors, if not provided
        ax = plot_vals.plot(kind='barh', figsize=figsize, ax=ax)
        
    # set titles and axis labels
    ax.set(xlabel='Importance', 
           ylabel='Feature Names', 
           title=title)
    
    ## return ax in case want to continue to update/modify figure
    return ax

# %%
def get_coeffs_linreg(lin_reg, feature_names = None, sort=True,ascending=True,
                     name='LinearRegression Coefficients'):
    if feature_names is None:
        feature_names = lin_reg.feature_names_in_
    ## Saving the coefficients
    coeffs = pd.Series(lin_reg.coef_, index= feature_names)
    coeffs['intercept'] = lin_reg.intercept_
    if sort==True:
        coeffs = coeffs.sort_values(ascending=ascending)
    return coeffs

# %%
def plot_coeffs(coeffs, top_n=None, figsize=(4,5), 
                intercept=False, intercept_name="intercept", 
                annotate=False, ha='left', va='center', size=12, 
                xytext=(4,0), textcoords='offset points'):
    """ Plots the top_n coefficients from a Series, with optional annotations.
    """
    # Drop intercept if intercept=False and 
    if (intercept == False) & (intercept_name in coeffs.index):
        coeffs = coeffs.drop(intercept_name)
    if top_n == None:
        ## sort all features and set title
        plot_vals = coeffs.sort_values()
        title = "All Coefficients - Ranked by Magnitude"
    else:
        ## rank the coeffs and select the top_n
        coeff_rank = coeffs.abs().rank().sort_values(ascending=False)
        top_n_features = coeff_rank.head(top_n)
        
        ## sort features and keep top_n and set title
        plot_vals = coeffs.loc[top_n_features.index].sort_values()
        title = f"Top {top_n} Largest Coefficients"
    ## plotting top N importances
    ax = plot_vals.plot(kind='barh', figsize=figsize)
    ax.set(xlabel='Coefficient', 
            ylabel='Feature Names', 
            title=title)
    ax.axvline(0, color='k')
    if annotate == True:
        annotate_hbars(ax, ha=ha, va=va, size=size, xytext=xytext, textcoords=textcoords)
    return ax

# %%
def annotate_hbars(ax, ha='left', va='center', size=12, xytext=(4,0),
                  textcoords='offset points'):
    for bar in ax.patches:
    
        ## calculate center of bar
        bar_ax = bar.get_y() + bar.get_height() / 2
        ## get the value to annotate
        val = bar.get_width()
        if val < 0:
            val_pos = 0
        else:
            val_pos = val
        # ha and va stand for the horizontal and vertical alignment
        ax.annotate(f"{val:.3f}", (val_pos,bar_ax), ha=ha, va=va, size=size,
                        xytext=xytext, textcoords=textcoords)

# %% [markdown]
#   ---
# ## Prepare the Data for Machine Learning - Revisited

# %% [markdown]
# ### Imports

# %%
## Our standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

## Preprocessing tools
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer

## Models & evaluation metrics
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import joblib

## setting random state for reproducibility
SEED = 321
np.random.seed(SEED)
## set pandas to display more columns
pd.set_option('display.max_columns',50)

# %% [markdown]
# ### Loading Data

# %%
filename_2 = 'sales_predictions_2023.csv'
data = pd.read_csv(filename_2)

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# **Dropping Duplicates**

# %% [markdown]
# I start by cleaning my data and dropping any duplicate rows using an if statement

# %%
# If statement where if there are 0 duplicate rows, print: "There are 0 duplicate rows, no need to delete any duplicate rows"
# Otherwise, if there are any duplicate's - drop them and output "x duplicate rows have been dropped". 

if data.duplicated().sum() == 0:
  print(f'There are {data.duplicated().sum()} duplicate rows, no need to delete any duplicate rows.')
else:
  data.drop_duplicates(inplace=True)
  print(f'{data.duplicated().sum()} duplicate rows have been dropped.')
# Out:
# There are 0 duplicate rows, no need to delete any duplicate rows.

# %% [markdown]
# **Identifying Missing Values**

# %% [markdown]
# Here I will only identify the missing values which will then be dealt with later on in this section - I note that the Item_Weight and Outlet_Size columns are both missing 17% and 28% of their data

# %%
# Print statement that identifies how many total missing values
print(f'There are {data.isna().sum().sum()} missing values.')
# Out:
# There are 3873 missing values.

# %%
# Print statement that displays the percentage of missing values from each column
print(data.isna().sum()/len(data)*100)
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %% [markdown]
# **Fix Inconsistences in Categorical Data**

# %% [markdown]
# In this next section I will fix all the inconsistincies in the categorical data. I will adjust the Item_Fat_Content column so that has two clean strings "Low Fat" and "Regular"

# %%
# Create filter that contains all the object data types of the data frame
data_types = data.dtypes
object_data_types_filter = data_types[(data_types == "object")]

# %%
# View the filter output to check the object columns are all there
object_data_types_filter
# Out:
# Item_Identifier         object
# Item_Fat_Content        object
# Item_Type               object
# Outlet_Identifier       object
# Outlet_Size             object
# Outlet_Location_Type    object
# Outlet_Type             object
# dtype: object

# %%
# View the index of the object column names 
object_data_types_filter.index
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
# For statement that loops through the index and prints out the unique values from each object column
for column in object_data_types_filter.index:
    print(column)
    print(data[column].unique())
    print('\n')
# Out:
# Item_Identifier
# ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05']
#
#
# Item_Fat_Content
# ['Low Fat' 'Regular' 'low fat' 'LF' 'reg']
#
#
# Item_Type
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
#
#
# Outlet_Identifier
# ['OUT049' 'OUT018' 'OUT010' 'OUT013' 'OUT027' 'OUT045' 'OUT017' 'OUT046'
#  'OUT035' 'OUT019']
#
#
# Outlet_Size
# ['Medium' nan 'High' 'Small']
#
#
# Outlet_Location_Type
# ['Tier 1' 'Tier 3' 'Tier 2']
#
#
# Outlet_Type
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %%
#Fix the odd spellings in the Item_Fat_Content colomn of low fat and regular to all be consistent
data['Item_Fat_Content'] = data['Item_Fat_Content'].replace('low fat', 'Low Fat')
data['Item_Fat_Content'] = data['Item_Fat_Content'].replace({'low fat': 'Low Fat', 'LF': 'Low Fat', 'reg': 'Regular'})

# %%
# For statement that loops through the index and prints out the unique values from each object column
for column in object_data_types_filter.index:
    print(column)
    print(data[column].unique())
    print('\n')
# Out:
# Item_Identifier
# ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05']
#
#
# Item_Fat_Content
# ['Low Fat' 'Regular']
#
#
# Item_Type
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
#
#
# Outlet_Identifier
# ['OUT049' 'OUT018' 'OUT010' 'OUT013' 'OUT027' 'OUT045' 'OUT017' 'OUT046'
#  'OUT035' 'OUT019']
#
#
# Outlet_Size
# ['Medium' nan 'High' 'Small']
#
#
# Outlet_Location_Type
# ['Tier 1' 'Tier 3' 'Tier 2']
#
#
# Outlet_Type
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %% [markdown]
# Below I check the numerical columns to see if there are any outliers to take care of, and all seem to be within reason and nothing is sticking out to me as being an outlier from what I can tell. I also check to see if there are any null values in the target column but there are 0 so it's time to move on to the next section.

# %%
# Display desriptive statitistics for the numeric columns
data.describe(include='number')
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# Display desriptive statitistics for the object columns
data.describe(include='object')
# Out:
#        Item_Identifier Item_Fat_Content              Item_Type  \
# count             8523             8523                   8523
# unique            1559                2                     16
# top              FDW13          Low Fat  Fruits and Vegetables
# freq                10             5517                   1232
#
#        Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# count               8523        6113                 8523               8523
# unique                10           3                    3                  4
# top               OUT027      Medium               Tier 3  Supermarket Type1
# freq                 935        2793                 3350               5577

# %%
# Check target for null values
data['Item_Outlet_Sales'].isna().sum()
# Out:
# 0

# %% [markdown]
# For my last bit of data cleaning I decide to drop the Item_identifier column as that column is not useful for my process as it contains an id for each product that wont help in the analysis done for machine learning

# %%
# Dropping the Item_identifier column 
data = data.drop('Item_Identifier', axis=1)

# %% [markdown]
#  ---
#
#
# ### Pre-Processing Data

# %% [markdown]
# Now that I have confirmed there are no duplicates, cleaned up the categorical data and checked for outliers - I will proceed to Train, Test and Split the data

# %% [markdown]
# #### Train/Test/Split

# %%
# split X and y, you are predicting calories per serving
X = data.drop(columns=['Item_Outlet_Sales']).copy()
y = data['Item_Outlet_Sales'].copy()

# split training and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.30 , random_state=SEED)

# %% [markdown]
# #### Preprocessor & ColumnTransformer

# %%
## Make numeric preprocessing pipeline
num_sel = make_column_selector(dtype_include='number')
num_pipe = make_pipeline(SimpleImputer(strategy='mean'))
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer())])

# %%
## Make categorical preprocessing pipeline
cat_sel = make_column_selector(dtype_include='object')
cat_pipe = make_pipeline(SimpleImputer(strategy='constant',
                                       fill_value='MISSING'),
                         OneHotEncoder(handle_unknown='ignore', sparse=False))

# %%
## make the preprocessing column transformer
preprocessor = make_column_transformer((num_pipe, num_sel),
                                       (cat_pipe,cat_sel),)
preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x000001A4E9CD5FD0>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='MISSING',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x000001A4E9CFF940>)])

# %% [markdown]
# #### Fit column transformer and run get_feature_names_out

# %%
## fit column transformer and run get_feature_names_out
preprocessor.fit(X_train)
feature_names = preprocessor.get_feature_names_out()
feature_names
# Out:
# array(['pipeline-1__Item_Weight', 'pipeline-1__Item_Visibility',
#        'pipeline-1__Item_MRP', 'pipeline-1__Outlet_Establishment_Year',
#        'pipeline-2__Item_Fat_Content_Low Fat',
#        'pipeline-2__Item_Fat_Content_Regular',
#        'pipeline-2__Item_Type_Baking Goods',
#        'pipeline-2__Item_Type_Breads', 'pipeline-2__Item_Type_Breakfast',
#        'pipeline-2__Item_Type_Canned', 'pipeline-2__Item_Type_Dairy',
#        'pipeline-2__Item_Type_Frozen Foods',
#        'pipeline-2__Item_Type_Fruits and Vegetables',
#        'pipeline-2__Item_Type_Hard Drinks',
#        'pipeline-2__Item_Type_Health and Hygiene',
#        'pipeline-2__Item_Type_Household', 'pipeline-2__Item_Type_Meat',
#        'pipeline-2__Item_Type_Others', 'pipeline-2__Item_Type_Seafood',
#        'pipeline-2__Item_Type_Snack Foods',
#        'pipeline-2__Item_Type_Soft Drinks',
#        'pipeline-2__Item_Type_Starchy Foods',
#        'pipeline-2__Outlet_Identifier_OUT010',
#        'pipeline-2__Outlet_Identifier_OUT013',
#        'pipeline-2__Outlet_Identifier_OUT017',
#        'pipeline-2__Outlet_Identifier_OUT018',
#        'pipeline-2__Outlet_Identifier_OUT019',
#        'pipeline-2__Outlet_Identifier_OUT027',
#        'pipeline-2__Outlet_Identifier_OUT035',
#        'pipeline-2__Outlet_Identifier_OUT045',
#        'pipeline-2__Outlet_Identifier_OUT046',
#        'pipeline-2__Outlet_Identifier_OUT049',
#        'pipeline-2__Outlet_Size_High', 'pipeline-2__Outlet_Size_MISSING',
#        'pipeline-2__Outlet_Size_Medium', 'pipeline-2__Outlet_Size_Small',
#        'pipeline-2__Outlet_Location_Type_Tier 1',
#        'pipeline-2__Outlet_Location_Type_Tier 2',
#        'pipeline-2__Outlet_Location_Type_Tier 3',
#        'pipeline-2__Outlet_Type_Grocery Store',
#        'pipeline-2__Outlet_Type_Supermarket Type1',
#        'pipeline-2__Outlet_Type_Supermarket Type2',
#        'pipeline-2__Outlet_Type_Supermarket Type3'], dtype=object)

# %%
#remake the X_train and X_test as dataframes with the new feature names
X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                          columns=preprocessor.get_feature_names_out(),
                         index=X_train.index)
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                          columns=preprocessor.get_feature_names_out(),
                         index=X_test.index)
display(X_train_df)
# Out:
#       pipeline-1__Item_Weight  pipeline-1__Item_Visibility  \
# 7394                10.195000                     0.000000
# 2736                 7.435000                     0.084452
# 475                 14.300000                     0.127542
# 7357                20.500000                     0.112585
# 4532                15.850000                     0.007145
# ...                       ...                          ...
# 3482                12.852984                     0.012216
# 8360                11.500000                     0.014884
# 5929                 5.110000                     0.034945
# 4220                 6.550000                     0.034800
# 6682                 7.810000                     0.067730
#
#       pipeline-1__Item_MRP  pipeline-1__Outlet_Establishment_Year  \
# 7394              139.5838                                 2009.0
# 2736              165.2158                                 1997.0
# 475                84.9224                                 1997.0
# 7357              192.0478                                 1999.0
# 4532               41.0480                                 2004.0
# ...                    ...                                    ...
# 3482              162.7894                                 1985.0
# 8360              174.5080                                 1999.0
# 5929              161.1210                                 2002.0
# 4220              157.5288                                 2007.0
# 6682              242.6486                                 2009.0
#
#       pipeline-2__Item_Fat_Content_Low Fat  \
# 7394                                   0.0
# 2736                                   1.0
# 475                                    1.0
# 7357                                   0.0
# 4532                                   0.0
# ...                                    ...
# 3482                                   1.0
# 8360                                   1.0
# 5929                                   1.0
# 4220                                   0.0
# 6682                                   1.0
#
#       pipeline-2__Item_Fat_Content_Regular  \
# 7394                                   1.0
# 2736                                   0.0
# 475                                    0.0
# 7357                                   1.0
# 4532                                   1.0
# ...                                    ...
# 3482                                   0.0
# 8360                                   0.0
# 5929                                   0.0
# 4220                                   1.0
# 6682                                   0.0
#
#       pipeline-2__Item_Type_Baking Goods  pipeline-2__Item_Type_Breads  \
# 7394                                 0.0                           0.0
# 2736                                 0.0                           0.0
# 475                                  0.0                           0.0
# 7357                                 0.0                           0.0
# 4532                                 0.0                           0.0
# ...                                  ...                           ...
# 3482                                 0.0                           0.0
# 8360                                 0.0                           0.0
# 5929                                 0.0                           0.0
# 4220                                 0.0                           1.0
# 6682                                 0.0                           0.0
#
#       pipeline-2__Item_Type_Breakfast  pipeline-2__Item_Type_Canned  \
# 7394                              0.0                           0.0
# 2736                              0.0                           0.0
# 475                               0.0                           0.0
# 7357                              0.0                           0.0
# 4532                              0.0                           0.0
# ...                               ...                           ...
# 3482                              0.0                           0.0
# 8360                              0.0                           0.0
# 5929                              0.0                           0.0
# 4220                              0.0                           0.0
# 6682                              0.0                           0.0
#
#       pipeline-2__Item_Type_Dairy  pipeline-2__Item_Type_Frozen Foods  \
# 7394                          0.0                                 1.0
# 2736                          0.0                                 0.0
# 475                           0.0                                 1.0
# 7357                          0.0                                 0.0
# 4532                          0.0                                 0.0
# ...                           ...                                 ...
# 3482                          0.0                                 0.0
# 8360                          0.0                                 0.0
# 5929                          0.0                                 0.0
# 4220                          0.0                                 0.0
# 6682                          0.0                                 0.0
#
#       pipeline-2__Item_Type_Fruits and Vegetables  \
# 7394                                          0.0
# 2736                                          0.0
# 475                                           0.0
# 7357                                          1.0
# 4532                                          0.0
# ...                                           ...
# 3482                                          1.0
# 8360                                          0.0
# 5929                                          0.0
# 4220                                          0.0
# 6682                                          0.0
#
#       pipeline-2__Item_Type_Hard Drinks  \
# 7394                                0.0
# 2736                                0.0
# 475                                 0.0
# 7357                                0.0
# 4532                                0.0
# ...                                 ...
# 3482                                0.0
# 8360                                0.0
# 5929                                0.0
# 4220                                0.0
# 6682                                0.0
#
#       pipeline-2__Item_Type_Health and Hygiene  \
# 7394                                       0.0
# 2736                                       0.0
# 475                                        0.0
# 7357                                       0.0
# 4532                                       0.0
# ...                                        ...
# 3482                                       0.0
# 8360                                       0.0
# 5929                                       0.0
# 4220                                       0.0
# 6682                                       0.0
#
#       pipeline-2__Item_Type_Household  pipeline-2__Item_Type_Meat  \
# 7394                              0.0                         0.0
# 2736                              0.0                         0.0
# 475                               0.0                         0.0
# 7357                              0.0                         0.0
# 4532                              0.0                         0.0
# ...                               ...                         ...
# 3482                              0.0                         0.0
# 8360                              0.0                         0.0
# 5929                              1.0                         0.0
# 4220                              0.0                         0.0
# 6682                              0.0                         0.0
#
#       pipeline-2__Item_Type_Others  pipeline-2__Item_Type_Seafood  \
# 7394                           0.0                            0.0
# 2736                           0.0                            0.0
# 475                            0.0                            0.0
# 7357                           0.0                            0.0
# 4532                           0.0                            0.0
# ...                            ...                            ...
# 3482                           0.0                            0.0
# 8360                           0.0                            0.0
# 5929                           0.0                            0.0
# 4220                           0.0                            0.0
# 6682                           0.0                            0.0
#
#       pipeline-2__Item_Type_Snack Foods  pipeline-2__Item_Type_Soft Drinks  \
# 7394                                0.0                                0.0
# 2736                                0.0                                0.0
# 475                                 0.0                                0.0
# 7357                                0.0                                0.0
# 4532                                1.0                                0.0
# ...                                 ...                                ...
# 3482                                0.0                                0.0
# 8360                                0.0                                0.0
# 5929                                0.0                                0.0
# 4220                                0.0                                0.0
# 6682                                0.0                                1.0
#
#       pipeline-2__Item_Type_Starchy Foods  \
# 7394                                  0.0
# 2736                                  1.0
# 475                                   0.0
# 7357                                  0.0
# 4532                                  0.0
# ...                                   ...
# 3482                                  0.0
# 8360                                  1.0
# 5929                                  0.0
# 4220                                  0.0
# 6682                                  0.0
#
#       pipeline-2__Outlet_Identifier_OUT010  \
# 7394                                   0.0
# 2736                                   0.0
# 475                                    0.0
# 7357                                   0.0
# 4532                                   0.0
# ...                                    ...
# 3482                                   0.0
# 8360                                   0.0
# 5929                                   0.0
# 4220                                   0.0
# 6682                                   0.0
#
#       pipeline-2__Outlet_Identifier_OUT013  \
# 7394                                   0.0
# 2736                                   0.0
# 475                                    0.0
# 7357                                   0.0
# 4532                                   0.0
# ...                                    ...
# 3482                                   0.0
# 8360                                   0.0
# 5929                                   0.0
# 4220                                   0.0
# 6682                                   0.0
#
#       pipeline-2__Outlet_Identifier_OUT017  \
# 7394                                   0.0
# 2736                                   0.0
# 475                                    0.0
# 7357                                   0.0
# 4532                                   0.0
# ...                                    ...
# 3482                                   0.0
# 8360                                   0.0
# 5929                                   0.0
# 4220                                   1.0
# 6682                                   0.0
#
#       pipeline-2__Outlet_Identifier_OUT018  \
# 7394                                   1.0
# 2736                                   0.0
# 475                                    0.0
# 7357                                   0.0
# 4532                                   0.0
# ...                                    ...
# 3482                                   0.0
# 8360                                   0.0
# 5929                                   0.0
# 4220                                   0.0
# 6682                                   1.0
#
#       pipeline-2__Outlet_Identifier_OUT019  \
# 7394                                   0.0
# 2736                                   0.0
# 475                                    0.0
# 7357                                   0.0
# 4532                                   0.0
# ...                                    ...
# 3482                                   0.0
# 8360                                   0.0
# 5929                                   0.0
# 4220                                   0.0
# 6682                                   0.0
#
#       pipeline-2__Outlet_Identifier_OUT027  \
# 7394                                   0.0
# 2736                                   0.0
# 475                                    0.0
# 7357                                   0.0
# 4532                                   0.0
# ...                                    ...
# 3482                                   1.0
# 8360                                   0.0
# 5929                                   0.0
# 4220                                   0.0
# 6682                                   0.0
#
#       pipeline-2__Outlet_Identifier_OUT035  \
# 7394                                   0.0
# 2736                                   0.0
# 475                                    0.0
# 7357                                   0.0
# 4532                                   1.0
# ...                                    ...
# 3482                                   0.0
# 8360                                   0.0
# 5929                                   0.0
# 4220                                   0.0
# 6682                                   0.0
#
#       pipeline-2__Outlet_Identifier_OUT045  \
# 7394                                   0.0
# 2736                                   0.0
# 475                                    0.0
# 7357                                   0.0
# 4532                                   0.0
# ...                                    ...
# 3482                                   0.0
# 8360                                   0.0
# 5929                                   1.0
# 4220                                   0.0
# 6682                                   0.0
#
#       pipeline-2__Outlet_Identifier_OUT046  \
# 7394                                   0.0
# 2736                                   1.0
# 475                                    1.0
# 7357                                   0.0
# 4532                                   0.0
# ...                                    ...
# 3482                                   0.0
# 8360                                   0.0
# 5929                                   0.0
# 4220                                   0.0
# 6682                                   0.0
#
#       pipeline-2__Outlet_Identifier_OUT049  pipeline-2__Outlet_Size_High  \
# 7394                                   0.0                           0.0
# 2736                                   0.0                           0.0
# 475                                    0.0                           0.0
# 7357                                   1.0                           0.0
# 4532                                   0.0                           0.0
# ...                                    ...                           ...
# 3482                                   0.0                           0.0
# 8360                                   1.0                           0.0
# 5929                                   0.0                           0.0
# 4220                                   0.0                           0.0
# 6682                                   0.0                           0.0
#
#       pipeline-2__Outlet_Size_MISSING  pipeline-2__Outlet_Size_Medium  \
# 7394                              0.0                             1.0
# 2736                              0.0                             0.0
# 475                               0.0                             0.0
# 7357                              0.0                             1.0
# 4532                              0.0                             0.0
# ...                               ...                             ...
# 3482                              0.0                             1.0
# 8360                              0.0                             1.0
# 5929                              1.0                             0.0
# 4220                              1.0                             0.0
# 6682                              0.0                             1.0
#
#       pipeline-2__Outlet_Size_Small  pipeline-2__Outlet_Location_Type_Tier 1  \
# 7394                            0.0                                      0.0
# 2736                            1.0                                      1.0
# 475                             1.0                                      1.0
# 7357                            0.0                                      1.0
# 4532                            1.0                                      0.0
# ...                             ...                                      ...
# 3482                            0.0                                      0.0
# 8360                            0.0                                      1.0
# 5929                            0.0                                      0.0
# 4220                            0.0                                      0.0
# 6682                            0.0                                      0.0
#
#       pipeline-2__Outlet_Location_Type_Tier 2  \
# 7394                                      0.0
# 2736                                      0.0
# 475                                       0.0
# 7357                                      0.0
# 4532                                      1.0
# ...                                       ...
# 3482                                      0.0
# 8360                                      0.0
# 5929                                      1.0
# 4220                                      1.0
# 6682                                      0.0
#
#       pipeline-2__Outlet_Location_Type_Tier 3  \
# 7394                                      1.0
# 2736                                      0.0
# 475                                       0.0
# 7357                                      0.0
# 4532                                      0.0
# ...                                       ...
# 3482                                      1.0
# 8360                                      0.0
# 5929                                      0.0
# 4220                                      0.0
# 6682                                      1.0
#
#       pipeline-2__Outlet_Type_Grocery Store  \
# 7394                                    0.0
# 2736                                    0.0
# 475                                     0.0
# 7357                                    0.0
# 4532                                    0.0
# ...                                     ...
# 3482                                    0.0
# 8360                                    0.0
# 5929                                    0.0
# 4220                                    0.0
# 6682                                    0.0
#
#       pipeline-2__Outlet_Type_Supermarket Type1  \
# 7394                                        0.0
# 2736                                        1.0
# 475                                         1.0
# 7357                                        1.0
# 4532                                        1.0
# ...                                         ...
# 3482                                        0.0
# 8360                                        1.0
# 5929                                        1.0
# 4220                                        1.0
# 6682                                        0.0
#
#       pipeline-2__Outlet_Type_Supermarket Type2  \
# 7394                                        1.0
# 2736                                        0.0
# 475                                         0.0
# 7357                                        0.0
# 4532                                        0.0
# ...                                         ...
# 3482                                        0.0
# 8360                                        0.0
# 5929                                        0.0
# 4220                                        0.0
# 6682                                        1.0
#
#       pipeline-2__Outlet_Type_Supermarket Type3
# 7394                                        0.0
# 2736                                        0.0
# 475                                         0.0
# 7357                                        0.0
# 4532                                        0.0
# ...                                         ...
# 3482                                        1.0
# 8360                                        0.0
# 5929                                        0.0
# 4220                                        0.0
# 6682                                        0.0
#
# [5966 rows x 43 columns]

# %% [markdown]
# #### LinearRegression

# %%
lin_reg= LinearRegression()
lin_reg.fit(X_train_df,y_train)
evaluate_regression(lin_reg, X_train_df, y_train, 
                    X_test_df, y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_02556">
#   <thead>
#     <tr>
#       <th id="T_02556_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_02556_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_02556_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_02556_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_02556_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_02556_row0_col1" class="data row0 col1" >0.56</td>
#       <td id="T_02556_row0_col2" class="data row0 col2" >827.25</td>
#       <td id="T_02556_row0_col3" class="data row0 col3" >1,115.13</td>
#     </tr>
#     <tr>
#       <td id="T_02556_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_02556_row1_col1" class="data row1 col1" >0.56</td>
#       <td id="T_02556_row1_col2" class="data row1 col2" >853.22</td>
#       <td id="T_02556_row1_col3" class="data row1 col3" >1,156.22</td>
#     </tr>
#   </tbody>
# </table>

# %%
## Checking the number of coeffs matches the # of feature names
print(len(lin_reg.coef_))
len(feature_names)
# Out:
# 43
# 43

# %%
## Saving the coefficients as a pandas series
coeffs = pd.Series(lin_reg.coef_, index= feature_names)
coeffs
# Out:
# pipeline-1__Item_Weight                          1.321998
# pipeline-1__Item_Visibility                   -239.398108
# pipeline-1__Item_MRP                            15.506730
# pipeline-1__Outlet_Establishment_Year          -14.223127
# pipeline-2__Item_Fat_Content_Low Fat           -17.594646
# pipeline-2__Item_Fat_Content_Regular            17.594646
# pipeline-2__Item_Type_Baking Goods              -6.324867
# pipeline-2__Item_Type_Breads                   -38.061736
# pipeline-2__Item_Type_Breakfast                  7.727757
# pipeline-2__Item_Type_Canned                    34.969444
# pipeline-2__Item_Type_Dairy                    -38.982201
# pipeline-2__Item_Type_Frozen Foods               4.051781
# pipeline-2__Item_Type_Fruits and Vegetables     21.378862
# pipeline-2__Item_Type_Hard Drinks               55.959398
# pipeline-2__Item_Type_Health and Hygiene       -43.807077
# pipeline-2__Item_Type_Household                -67.470022
# pipeline-2__Item_Type_Meat                      -6.296356
# pipeline-2__Item_Type_Others                    21.833069
# pipeline-2__Item_Type_Seafood                  147.745846
# pipeline-2__Item_Type_Snack Foods               -8.962712
# pipeline-2__Item_Type_Soft Drinks              -98.878993
# pipeline-2__Item_Type_Starchy Foods             15.117805
# pipeline-2__Outlet_Identifier_OUT010          -407.862062
# pipeline-2__Outlet_Identifier_OUT013           -68.682624
# pipeline-2__Outlet_Identifier_OUT017           204.954236
# pipeline-2__Outlet_Identifier_OUT018           -95.089419
# pipeline-2__Outlet_Identifier_OUT019          -465.760972
# pipeline-2__Outlet_Identifier_OUT027           581.879040
# pipeline-2__Outlet_Identifier_OUT035            80.371444
# pipeline-2__Outlet_Identifier_OUT045           -43.399600
# pipeline-2__Outlet_Identifier_OUT046           290.510918
# pipeline-2__Outlet_Identifier_OUT049           -76.920961
# pipeline-2__Outlet_Size_High                   -68.682624
# pipeline-2__Outlet_Size_MISSING               -246.307427
# pipeline-2__Outlet_Size_Medium                 409.868660
# pipeline-2__Outlet_Size_Small                  -94.878610
# pipeline-2__Outlet_Location_Type_Tier 1       -252.171016
# pipeline-2__Outlet_Location_Type_Tier 2        241.926080
# pipeline-2__Outlet_Location_Type_Tier 3         10.244935
# pipeline-2__Outlet_Type_Grocery Store         -873.623034
# pipeline-2__Outlet_Type_Supermarket Type1      386.833413
# pipeline-2__Outlet_Type_Supermarket Type2      -95.089419
# pipeline-2__Outlet_Type_Supermarket Type3      581.879040
# dtype: float64

# %%
# use .loc to add the intercept to the series
coeffs.loc['intercept'] = lin_reg.intercept_
coeffs
# Out:
# pipeline-1__Item_Weight                            1.321998
# pipeline-1__Item_Visibility                     -239.398108
# pipeline-1__Item_MRP                              15.506730
# pipeline-1__Outlet_Establishment_Year            -14.223127
# pipeline-2__Item_Fat_Content_Low Fat             -17.594646
# pipeline-2__Item_Fat_Content_Regular              17.594646
# pipeline-2__Item_Type_Baking Goods                -6.324867
# pipeline-2__Item_Type_Breads                     -38.061736
# pipeline-2__Item_Type_Breakfast                    7.727757
# pipeline-2__Item_Type_Canned                      34.969444
# pipeline-2__Item_Type_Dairy                      -38.982201
# pipeline-2__Item_Type_Frozen Foods                 4.051781
# pipeline-2__Item_Type_Fruits and Vegetables       21.378862
# pipeline-2__Item_Type_Hard Drinks                 55.959398
# pipeline-2__Item_Type_Health and Hygiene         -43.807077
# pipeline-2__Item_Type_Household                  -67.470022
# pipeline-2__Item_Type_Meat                        -6.296356
# pipeline-2__Item_Type_Others                      21.833069
# pipeline-2__Item_Type_Seafood                    147.745846
# pipeline-2__Item_Type_Snack Foods                 -8.962712
# pipeline-2__Item_Type_Soft Drinks                -98.878993
# pipeline-2__Item_Type_Starchy Foods               15.117805
# pipeline-2__Outlet_Identifier_OUT010            -407.862062
# pipeline-2__Outlet_Identifier_OUT013             -68.682624
# pipeline-2__Outlet_Identifier_OUT017             204.954236
# pipeline-2__Outlet_Identifier_OUT018             -95.089419
# pipeline-2__Outlet_Identifier_OUT019            -465.760972
# pipeline-2__Outlet_Identifier_OUT027             581.879040
# pipeline-2__Outlet_Identifier_OUT035              80.371444
# pipeline-2__Outlet_Identifier_OUT045             -43.399600
# pipeline-2__Outlet_Identifier_OUT046             290.510918
# pipeline-2__Outlet_Identifier_OUT049             -76.920961
# pipeline-2__Outlet_Size_High                     -68.682624
# pipeline-2__Outlet_Size_MISSING                 -246.307427
# pipeline-2__Outlet_Size_Medium                   409.868660
# pipeline-2__Outlet_Size_Small                    -94.878610
# pipeline-2__Outlet_Location_Type_Tier 1         -252.171016
# pipeline-2__Outlet_Location_Type_Tier 2          241.926080
# pipeline-2__Outlet_Location_Type_Tier 3           10.244935
# pipeline-2__Outlet_Type_Grocery Store           -873.623034
# pipeline-2__Outlet_Type_Supermarket Type1        386.833413
# pipeline-2__Outlet_Type_Supermarket Type2        -95.089419
# pipeline-2__Outlet_Type_Supermarket Type3        581.879040
# intercept                                      28141.277839
# dtype: float64

# %%
pd.set_option('display.float_format', lambda x: f"{x:,.2f}")
coeffs
# Out:
# pipeline-1__Item_Weight                            1.32
# pipeline-1__Item_Visibility                     -239.40
# pipeline-1__Item_MRP                              15.51
# pipeline-1__Outlet_Establishment_Year            -14.22
# pipeline-2__Item_Fat_Content_Low Fat             -17.59
# pipeline-2__Item_Fat_Content_Regular              17.59
# pipeline-2__Item_Type_Baking Goods                -6.32
# pipeline-2__Item_Type_Breads                     -38.06
# pipeline-2__Item_Type_Breakfast                    7.73
# pipeline-2__Item_Type_Canned                      34.97
# pipeline-2__Item_Type_Dairy                      -38.98
# pipeline-2__Item_Type_Frozen Foods                 4.05
# pipeline-2__Item_Type_Fruits and Vegetables       21.38
# pipeline-2__Item_Type_Hard Drinks                 55.96
# pipeline-2__Item_Type_Health and Hygiene         -43.81
# pipeline-2__Item_Type_Household                  -67.47
# pipeline-2__Item_Type_Meat                        -6.30
# pipeline-2__Item_Type_Others                      21.83
# pipeline-2__Item_Type_Seafood                    147.75
# pipeline-2__Item_Type_Snack Foods                 -8.96
# pipeline-2__Item_Type_Soft Drinks                -98.88
# pipeline-2__Item_Type_Starchy Foods               15.12
# pipeline-2__Outlet_Identifier_OUT010            -407.86
# pipeline-2__Outlet_Identifier_OUT013             -68.68
# pipeline-2__Outlet_Identifier_OUT017             204.95
# pipeline-2__Outlet_Identifier_OUT018             -95.09
# pipeline-2__Outlet_Identifier_OUT019            -465.76
# pipeline-2__Outlet_Identifier_OUT027             581.88
# pipeline-2__Outlet_Identifier_OUT035              80.37
# pipeline-2__Outlet_Identifier_OUT045             -43.40
# pipeline-2__Outlet_Identifier_OUT046             290.51
# pipeline-2__Outlet_Identifier_OUT049             -76.92
# pipeline-2__Outlet_Size_High                     -68.68
# pipeline-2__Outlet_Size_MISSING                 -246.31
# pipeline-2__Outlet_Size_Medium                   409.87
# pipeline-2__Outlet_Size_Small                    -94.88
# pipeline-2__Outlet_Location_Type_Tier 1         -252.17
# pipeline-2__Outlet_Location_Type_Tier 2          241.93
# pipeline-2__Outlet_Location_Type_Tier 3           10.24
# pipeline-2__Outlet_Type_Grocery Store           -873.62
# pipeline-2__Outlet_Type_Supermarket Type1        386.83
# pipeline-2__Outlet_Type_Supermarket Type2        -95.09
# pipeline-2__Outlet_Type_Supermarket Type3        581.88
# intercept                                     28,141.28
# dtype: float64

# %%
#checking for multicolunearity 
data.select_dtypes('object').nunique()
#checks to see if our categories have more than 1 option
# Out:
# Item_Fat_Content         2
# Item_Type               16
# Outlet_Identifier       10
# Outlet_Size              3
# Outlet_Location_Type     3
# Outlet_Type              4
# dtype: int64

# %% [markdown]
# - This seems about right with the data and number of categorical values there are

# %%
coeffs = get_coeffs_linreg(lin_reg)
coeffs
# Out:
# pipeline-2__Outlet_Type_Grocery Store           -873.62
# pipeline-2__Outlet_Identifier_OUT019            -465.76
# pipeline-2__Outlet_Identifier_OUT010            -407.86
# pipeline-2__Outlet_Location_Type_Tier 1         -252.17
# pipeline-2__Outlet_Size_MISSING                 -246.31
# pipeline-1__Item_Visibility                     -239.40
# pipeline-2__Item_Type_Soft Drinks                -98.88
# pipeline-2__Outlet_Identifier_OUT018             -95.09
# pipeline-2__Outlet_Type_Supermarket Type2        -95.09
# pipeline-2__Outlet_Size_Small                    -94.88
# pipeline-2__Outlet_Identifier_OUT049             -76.92
# pipeline-2__Outlet_Identifier_OUT013             -68.68
# pipeline-2__Outlet_Size_High                     -68.68
# pipeline-2__Item_Type_Household                  -67.47
# pipeline-2__Item_Type_Health and Hygiene         -43.81
# pipeline-2__Outlet_Identifier_OUT045             -43.40
# pipeline-2__Item_Type_Dairy                      -38.98
# pipeline-2__Item_Type_Breads                     -38.06
# pipeline-2__Item_Fat_Content_Low Fat             -17.59
# pipeline-1__Outlet_Establishment_Year            -14.22
# pipeline-2__Item_Type_Snack Foods                 -8.96
# pipeline-2__Item_Type_Baking Goods                -6.32
# pipeline-2__Item_Type_Meat                        -6.30
# pipeline-1__Item_Weight                            1.32
# pipeline-2__Item_Type_Frozen Foods                 4.05
# pipeline-2__Item_Type_Breakfast                    7.73
# pipeline-2__Outlet_Location_Type_Tier 3           10.24
# pipeline-2__Item_Type_Starchy Foods               15.12
# pipeline-1__Item_MRP                              15.51
# pipeline-2__Item_Fat_Content_Regular              17.59
# pipeline-2__Item_Type_Fruits and Vegetables       21.38
# pipeline-2__Item_Type_Others                      21.83
# pipeline-2__Item_Type_Canned                      34.97
# pipeline-2__Item_Type_Hard Drinks                 55.96
# pipeline-2__Outlet_Identifier_OUT035              80.37
# pipeline-2__Item_Type_Seafood                    147.75
# pipeline-2__Outlet_Identifier_OUT017             204.95
# pipeline-2__Outlet_Location_Type_Tier 2          241.93
# pipeline-2__Outlet_Identifier_OUT046             290.51
# pipeline-2__Outlet_Type_Supermarket Type1        386.83
# pipeline-2__Outlet_Size_Medium                   409.87
# pipeline-2__Outlet_Type_Supermarket Type3        581.88
# pipeline-2__Outlet_Identifier_OUT027             581.88
# intercept                                     28,141.28
# dtype: float64

# %% [markdown]
# ##### Impactful Coefficients

# %%
ax = plot_coeffs(coeffs,top_n=15)
annotate_hbars(ax)
#use custom function to annotate the bars in the chart

# %%
# Create a new figure
fig, ax = plt.subplots()

# Call your custom plotting function
plot_coeffs(coeffs, top_n=15, annotate=True)
# Out:
# <AxesSubplot: title={'center': 'Top 15 Largest Coefficients'}, xlabel='Coefficient', ylabel='Feature Names'>

# %% [markdown]
# **Interpretation**

# %% [markdown]
# - Outlet_identifier_OUT027, Outlet Type Supermarket Type3 and Outlet Size Medium all had the greatest impact
# - Outlet_identifier_OUT027 has the coefficient of 581.879 which means that type of store had a great impact on food sales
# - Supermarket Type 3 had 581.879 has a coefficient of 581.879 which also means this has a great impact on higher food sales
# - Outlet Size Medium has a coefficient of 409.869 which means that if the outlet is categorized as a size medium, it has a high impact as well

# %%
#save the chart as a png file
fig.savefig('LinearRegressionAnalysis.png',dpi=300)

# %% [markdown]
# #### RandomForest

# %%
# Create a new figure
fig, ax = plt.subplots()
reg = RandomForestRegressor()
reg.fit(X_train_df,y_train)
evaluate_regression(reg, X_train_df, y_train, X_test_df,y_test)
## Saving the feature importances
importances = get_importances(reg)
plot_importance(importances, top_n=10)
#save the chart as a png file
fig.savefig('RandomForestFeatureAnalysis.png',dpi=300);
# Out:
# <style type="text/css">
# </style>
# <table id="T_978df">
#   <thead>
#     <tr>
#       <th id="T_978df_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_978df_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_978df_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_978df_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_978df_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_978df_row0_col1" class="data row0 col1" >0.94</td>
#       <td id="T_978df_row0_col2" class="data row0 col2" >292.51</td>
#       <td id="T_978df_row0_col3" class="data row0 col3" >424.14</td>
#     </tr>
#     <tr>
#       <td id="T_978df_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_978df_row1_col1" class="data row1 col1" >0.56</td>
#       <td id="T_978df_row1_col2" class="data row1 col2" >817.23</td>
#       <td id="T_978df_row1_col3" class="data row1 col3" >1,162.28</td>
#     </tr>
#   </tbody>
# </table>

# %%
importances.sort_values(ascending=False).head(5)
# Out:
# pipeline-1__Item_MRP                    0.44
# pipeline-2__Outlet_Type_Grocery Store   0.19
# pipeline-1__Item_Visibility             0.10
# pipeline-1__Item_Weight                 0.05
# pipeline-1__Outlet_Establishment_Year   0.03
# Name: Feature Importance, dtype: float64

# %%
#before completing EDA, put the DF back together for plotting to include train and test values
plot_train = pd.concat([X_train_df,y_train],axis=1)
plot_test = pd.concat([X_test_df,y_test],axis=1)
plot_df = pd.concat([plot_train, plot_test])
plot_df
# Out:
#       pipeline-1__Item_Weight  pipeline-1__Item_Visibility  \
# 7394                    10.20                         0.00
# 2736                     7.43                         0.08
# 475                     14.30                         0.13
# 7357                    20.50                         0.11
# 4532                    15.85                         0.01
# ...                       ...                          ...
# 2917                     6.38                         0.08
# 6708                    12.85                         0.14
# 8255                    16.20                         0.06
# 7812                    17.75                         0.16
# 4461                    15.75                         0.06
#
#       pipeline-1__Item_MRP  pipeline-1__Outlet_Establishment_Year  \
# 7394                139.58                               2,009.00
# 2736                165.22                               1,997.00
# 475                  84.92                               1,997.00
# 7357                192.05                               1,999.00
# 4532                 41.05                               2,004.00
# ...                    ...                                    ...
# 2917                109.06                               2,009.00
# 6708                 93.81                               1,985.00
# 8255                 98.17                               2,007.00
# 7812                239.32                               1,998.00
# 4461                195.55                               2,009.00
#
#       pipeline-2__Item_Fat_Content_Low Fat  \
# 7394                                  0.00
# 2736                                  1.00
# 475                                   1.00
# 7357                                  0.00
# 4532                                  0.00
# ...                                    ...
# 2917                                  1.00
# 6708                                  1.00
# 8255                                  1.00
# 7812                                  1.00
# 4461                                  1.00
#
#       pipeline-2__Item_Fat_Content_Regular  \
# 7394                                  1.00
# 2736                                  0.00
# 475                                   0.00
# 7357                                  1.00
# 4532                                  1.00
# ...                                    ...
# 2917                                  0.00
# 6708                                  0.00
# 8255                                  0.00
# 7812                                  0.00
# 4461                                  0.00
#
#       pipeline-2__Item_Type_Baking Goods  pipeline-2__Item_Type_Breads  \
# 7394                                0.00                          0.00
# 2736                                0.00                          0.00
# 475                                 0.00                          0.00
# 7357                                0.00                          0.00
# 4532                                0.00                          0.00
# ...                                  ...                           ...
# 2917                                0.00                          0.00
# 6708                                0.00                          0.00
# 8255                                0.00                          0.00
# 7812                                0.00                          0.00
# 4461                                1.00                          0.00
#
#       pipeline-2__Item_Type_Breakfast  pipeline-2__Item_Type_Canned  \
# 7394                             0.00                          0.00
# 2736                             0.00                          0.00
# 475                              0.00                          0.00
# 7357                             0.00                          0.00
# 4532                             0.00                          0.00
# ...                               ...                           ...
# 2917                             0.00                          0.00
# 6708                             0.00                          1.00
# 8255                             0.00                          1.00
# 7812                             0.00                          0.00
# 4461                             0.00                          0.00
#
#       pipeline-2__Item_Type_Dairy  pipeline-2__Item_Type_Frozen Foods  \
# 7394                         0.00                                1.00
# 2736                         0.00                                0.00
# 475                          0.00                                1.00
# 7357                         0.00                                0.00
# 4532                         0.00                                0.00
# ...                           ...                                 ...
# 2917                         0.00                                0.00
# 6708                         0.00                                0.00
# 8255                         0.00                                0.00
# 7812                         0.00                                0.00
# 4461                         0.00                                0.00
#
#       pipeline-2__Item_Type_Fruits and Vegetables  \
# 7394                                         0.00
# 2736                                         0.00
# 475                                          0.00
# 7357                                         1.00
# 4532                                         0.00
# ...                                           ...
# 2917                                         0.00
# 6708                                         0.00
# 8255                                         0.00
# 7812                                         0.00
# 4461                                         0.00
#
#       pipeline-2__Item_Type_Hard Drinks  \
# 7394                               0.00
# 2736                               0.00
# 475                                0.00
# 7357                               0.00
# 4532                               0.00
# ...                                 ...
# 2917                               1.00
# 6708                               0.00
# 8255                               0.00
# 7812                               0.00
# 4461                               0.00
#
#       pipeline-2__Item_Type_Health and Hygiene  \
# 7394                                      0.00
# 2736                                      0.00
# 475                                       0.00
# 7357                                      0.00
# 4532                                      0.00
# ...                                        ...
# 2917                                      0.00
# 6708                                      0.00
# 8255                                      0.00
# 7812                                      1.00
# 4461                                      0.00
#
#       pipeline-2__Item_Type_Household  pipeline-2__Item_Type_Meat  \
# 7394                             0.00                        0.00
# 2736                             0.00                        0.00
# 475                              0.00                        0.00
# 7357                             0.00                        0.00
# 4532                             0.00                        0.00
# ...                               ...                         ...
# 2917                             0.00                        0.00
# 6708                             0.00                        0.00
# 8255                             0.00                        0.00
# 7812                             0.00                        0.00
# 4461                             0.00                        0.00
#
#       pipeline-2__Item_Type_Others  pipeline-2__Item_Type_Seafood  \
# 7394                          0.00                           0.00
# 2736                          0.00                           0.00
# 475                           0.00                           0.00
# 7357                          0.00                           0.00
# 4532                          0.00                           0.00
# ...                            ...                            ...
# 2917                          0.00                           0.00
# 6708                          0.00                           0.00
# 8255                          0.00                           0.00
# 7812                          0.00                           0.00
# 4461                          0.00                           0.00
#
#       pipeline-2__Item_Type_Snack Foods  pipeline-2__Item_Type_Soft Drinks  \
# 7394                               0.00                               0.00
# 2736                               0.00                               0.00
# 475                                0.00                               0.00
# 7357                               0.00                               0.00
# 4532                               1.00                               0.00
# ...                                 ...                                ...
# 2917                               0.00                               0.00
# 6708                               0.00                               0.00
# 8255                               0.00                               0.00
# 7812                               0.00                               0.00
# 4461                               0.00                               0.00
#
#       pipeline-2__Item_Type_Starchy Foods  \
# 7394                                 0.00
# 2736                                 1.00
# 475                                  0.00
# 7357                                 0.00
# 4532                                 0.00
# ...                                   ...
# 2917                                 0.00
# 6708                                 0.00
# 8255                                 0.00
# 7812                                 0.00
# 4461                                 0.00
#
#       pipeline-2__Outlet_Identifier_OUT010  \
# 7394                                  0.00
# 2736                                  0.00
# 475                                   0.00
# 7357                                  0.00
# 4532                                  0.00
# ...                                    ...
# 2917                                  0.00
# 6708                                  0.00
# 8255                                  0.00
# 7812                                  1.00
# 4461                                  0.00
#
#       pipeline-2__Outlet_Identifier_OUT013  \
# 7394                                  0.00
# 2736                                  0.00
# 475                                   0.00
# 7357                                  0.00
# 4532                                  0.00
# ...                                    ...
# 2917                                  0.00
# 6708                                  0.00
# 8255                                  0.00
# 7812                                  0.00
# 4461                                  0.00
#
#       pipeline-2__Outlet_Identifier_OUT017  \
# 7394                                  0.00
# 2736                                  0.00
# 475                                   0.00
# 7357                                  0.00
# 4532                                  0.00
# ...                                    ...
# 2917                                  0.00
# 6708                                  0.00
# 8255                                  1.00
# 7812                                  0.00
# 4461                                  0.00
#
#       pipeline-2__Outlet_Identifier_OUT018  \
# 7394                                  1.00
# 2736                                  0.00
# 475                                   0.00
# 7357                                  0.00
# 4532                                  0.00
# ...                                    ...
# 2917                                  1.00
# 6708                                  0.00
# 8255                                  0.00
# 7812                                  0.00
# 4461                                  1.00
#
#       pipeline-2__Outlet_Identifier_OUT019  \
# 7394                                  0.00
# 2736                                  0.00
# 475                                   0.00
# 7357                                  0.00
# 4532                                  0.00
# ...                                    ...
# 2917                                  0.00
# 6708                                  0.00
# 8255                                  0.00
# 7812                                  0.00
# 4461                                  0.00
#
#       pipeline-2__Outlet_Identifier_OUT027  \
# 7394                                  0.00
# 2736                                  0.00
# 475                                   0.00
# 7357                                  0.00
# 4532                                  0.00
# ...                                    ...
# 2917                                  0.00
# 6708                                  1.00
# 8255                                  0.00
# 7812                                  0.00
# 4461                                  0.00
#
#       pipeline-2__Outlet_Identifier_OUT035  \
# 7394                                  0.00
# 2736                                  0.00
# 475                                   0.00
# 7357                                  0.00
# 4532                                  1.00
# ...                                    ...
# 2917                                  0.00
# 6708                                  0.00
# 8255                                  0.00
# 7812                                  0.00
# 4461                                  0.00
#
#       pipeline-2__Outlet_Identifier_OUT045  \
# 7394                                  0.00
# 2736                                  0.00
# 475                                   0.00
# 7357                                  0.00
# 4532                                  0.00
# ...                                    ...
# 2917                                  0.00
# 6708                                  0.00
# 8255                                  0.00
# 7812                                  0.00
# 4461                                  0.00
#
#       pipeline-2__Outlet_Identifier_OUT046  \
# 7394                                  0.00
# 2736                                  1.00
# 475                                   1.00
# 7357                                  0.00
# 4532                                  0.00
# ...                                    ...
# 2917                                  0.00
# 6708                                  0.00
# 8255                                  0.00
# 7812                                  0.00
# 4461                                  0.00
#
#       pipeline-2__Outlet_Identifier_OUT049  pipeline-2__Outlet_Size_High  \
# 7394                                  0.00                          0.00
# 2736                                  0.00                          0.00
# 475                                   0.00                          0.00
# 7357                                  1.00                          0.00
# 4532                                  0.00                          0.00
# ...                                    ...                           ...
# 2917                                  0.00                          0.00
# 6708                                  0.00                          0.00
# 8255                                  0.00                          0.00
# 7812                                  0.00                          0.00
# 4461                                  0.00                          0.00
#
#       pipeline-2__Outlet_Size_MISSING  pipeline-2__Outlet_Size_Medium  \
# 7394                             0.00                            1.00
# 2736                             0.00                            0.00
# 475                              0.00                            0.00
# 7357                             0.00                            1.00
# 4532                             0.00                            0.00
# ...                               ...                             ...
# 2917                             0.00                            1.00
# 6708                             0.00                            1.00
# 8255                             1.00                            0.00
# 7812                             1.00                            0.00
# 4461                             0.00                            1.00
#
#       pipeline-2__Outlet_Size_Small  pipeline-2__Outlet_Location_Type_Tier 1  \
# 7394                           0.00                                     0.00
# 2736                           1.00                                     1.00
# 475                            1.00                                     1.00
# 7357                           0.00                                     1.00
# 4532                           1.00                                     0.00
# ...                             ...                                      ...
# 2917                           0.00                                     0.00
# 6708                           0.00                                     0.00
# 8255                           0.00                                     0.00
# 7812                           0.00                                     0.00
# 4461                           0.00                                     0.00
#
#       pipeline-2__Outlet_Location_Type_Tier 2  \
# 7394                                     0.00
# 2736                                     0.00
# 475                                      0.00
# 7357                                     0.00
# 4532                                     1.00
# ...                                       ...
# 2917                                     0.00
# 6708                                     0.00
# 8255                                     1.00
# 7812                                     0.00
# 4461                                     0.00
#
#       pipeline-2__Outlet_Location_Type_Tier 3  \
# 7394                                     1.00
# 2736                                     0.00
# 475                                      0.00
# 7357                                     0.00
# 4532                                     0.00
# ...                                       ...
# 2917                                     1.00
# 6708                                     1.00
# 8255                                     0.00
# 7812                                     1.00
# 4461                                     1.00
#
#       pipeline-2__Outlet_Type_Grocery Store  \
# 7394                                   0.00
# 2736                                   0.00
# 475                                    0.00
# 7357                                   0.00
# 4532                                   0.00
# ...                                     ...
# 2917                                   0.00
# 6708                                   0.00
# 8255                                   0.00
# 7812                                   1.00
# 4461                                   0.00
#
#       pipeline-2__Outlet_Type_Supermarket Type1  \
# 7394                                       0.00
# 2736                                       1.00
# 475                                        1.00
# 7357                                       1.00
# 4532                                       1.00
# ...                                         ...
# 2917                                       0.00
# 6708                                       0.00
# 8255                                       1.00
# 7812                                       0.00
# 4461                                       0.00
#
#       pipeline-2__Outlet_Type_Supermarket Type2  \
# 7394                                       1.00
# 2736                                       0.00
# 475                                        0.00
# 7357                                       0.00
# 4532                                       0.00
# ...                                         ...
# 2917                                       1.00
# 6708                                       0.00
# 8255                                       0.00
# 7812                                       0.00
# 4461                                       1.00
#
#       pipeline-2__Outlet_Type_Supermarket Type3  Item_Outlet_Sales
# 7394                                       0.00           4,495.48
# 2736                                       0.00           2,840.97
# 475                                        0.00           1,193.11
# 7357                                       0.00           1,549.98
# 4532                                       0.00             479.38
# ...                                         ...                ...
# 2917                                       0.00           1,941.47
# 6708                                       1.00           3,237.12
# 8255                                       0.00           2,696.49
# 7812                                       0.00             723.06
# 4461                                       0.00           1,174.47
#
# [8523 rows x 44 columns]

# %%
sns.regplot(data=plot_df, x='pipeline-1__Item_MRP',y='Item_Outlet_Sales');

# %% [markdown]
# - The higher the MRP the more it was used to split the samples and predict the final grade

# %%
sns.regplot(data=plot_df, x='pipeline-2__Outlet_Type_Grocery Store',y='Item_Outlet_Sales');

# %% [markdown]
# - The Type of grocery store was predominantly the 0.0 value that was used to predict the final grade

# %%
sns.regplot(data=plot_df, x='pipeline-1__Item_Visibility',y='Item_Outlet_Sales');

# %% [markdown]
# - The lower end of the Item_Visibility had a greater impact on predicting the final grade

# %%
sns.regplot(data=plot_df, x='pipeline-1__Item_Weight',y='Item_Outlet_Sales');

# %% [markdown]
# - Item weight was fairly evenly distributed, with a spike right in the middle around 12.5

# %%
sns.regplot(data=plot_df, x='pipeline-1__Outlet_Establishment_Year',y='Item_Outlet_Sales');

# %% [markdown]
# - This indicates that if the year of the Outlet was established was 195, that had the greatest impact on sales

# %% [markdown]
# #### Serialization

# %%
export = {'X_train':X_train_df,
         'y_train': y_train,
         'X_test':X_test_df,
          "y_test": y_test,
         'preprocessor':preprocessor,
         'RandomForestRegressor':reg,
         'LinearRegression':lin_reg}
joblib.dump(export, 'best-models.joblib')
# Out:
# ['best-models.joblib']

# %%
loaded = joblib.load('best-models.joblib')
loaded.keys()
# Out:
# dict_keys(['X_train', 'y_train', 'X_test', 'y_test', 'preprocessor', 'RandomForestRegressor', 'LinearRegression'])

# %%
X_train_df = loaded['X_train']
y_train = loaded['y_train']
X_test_df = loaded['X_test']
y_test = loaded['y_test']
preprocessor = loaded['preprocessor']
loaded_model = loaded['RandomForestRegressor']
